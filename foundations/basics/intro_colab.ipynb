# %% [markdown]
# This is my **first exp** with colab
#
# list of items:
# * Item1
# * Item2
#   * subitem 1
#
#
# equations:
# $$ y = w_0 + w_1 x_1 $$

# %%
place = "chennai"

# %% [markdown]
# for the cell separation and input fields : ref Insert -> add on form field

# %%
brightness = 38 # @param {"type":"slider","min":0,"max":100,"step":0.5}
count = 10 or 20 or 30

# %%
brightness
# Out:
# 38

# %%
animals = "Lion" # @param ["Lion","dog","cat", "horse"] {"allow-input":true}
animals
# Out:
# 'Lion'

# %%
color = 87 # @param {type: "slider", min: 0, max: 255, step: 1 }
# @markdown this can take variable colors
color
# Out:
# 87

# %%
val = input("give values")
# Out:
# give values40

# %%
val
# Out:
# '40'

# %%
#@title image
for i in range(5):
  print("you'll have an option to hide code : #@title ___")
# Out:
# you'll have an option to hide code : #@title ___
# you'll have an option to hide code : #@title ___
# you'll have an option to hide code : #@title ___
# you'll have an option to hide code : #@title ___
# you'll have an option to hide code : #@title ___

# %%
# @title Use code Insert-> snippets for quick code insertion

# %%
import pandas as pd
df = pd.DataFrame({
  'first_name': ['Sarah', 'John', 'Kyle', 'Joe'],
  'last_name': ['Connor', 'Connor', 'Reese', 'Bonnot'],
})
df.set_index('last_name', inplace=True)

df.loc[~df.index.duplicated(), :]
# Out:
#           first_name
# last_name
# Connor         Sarah
# Reese           Kyle
# Bonnot           Joe

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
date = '9/27/22 06:59 '

# %%
type(date)
# Out:
# str

# %%
import pandas as pd

# %%
date2 = pd.Timestamp(date).tz_localize("US/Pacific")

# %%
print(date2)
type(date2)
# Out:
# 2022-09-27 06:59:00-07:00
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ### For formu;la and all

# %% [markdown]
# # using latex format
# $ /s * 4$
#
# [link](www.google.com)

# %%
# %%html
# <marquee style='width: 100%; color: red;'><b> This is Colab</b></marquee>
# Out:
# <marquee style='width: 100%; color: red;'><b> This is Colab</b></marquee>

# %%
import google

# %%
dir(google)
# Out:
# ['__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_upb',
#  'api',
#  'api_core',
#  'auth',
#  'cloud',
#  'colab',
#  'iam',
#  'longrunning',
#  'oauth2',
#  'protobuf',
#  'resumable_media',
#  'rpc',
#  'type']

# %%
help(google.colab)
dir(google.colab)
# Out:
# Help on package google.colab in google:
#
# NAME
#     google.colab - Colab Python APIs.
#
# PACKAGE CONTENTS
#     _dataframe_summarizer
#     _debugpy
#     _debugpy_repr
#     _frontend
#     _generate_with_variable
#     _history
#     _import_hooks (package)
#     _import_magics
#     _inspector
#     _installation_commands
#     _interactive_table_helper
#     _interactive_table_hint_button
#     _ipython
#     _kernel
#     _login_handler
#     _message
#     _pip
#     _quickchart
#     _quickchart_dtypes
#     _quickchart_helpers
#     _quickchart_hint_button
#     _quickchart_lib
#     _reprs
#     _serverextension (package)
#     _shell
#     _shell_customizations
#     _system_commands
#     _tensorflow_magics
#     _variable_inspector
#     ai
#     auth
#     autoviz
#     data_table
#     drive
#     errors
#     files
#     html (package)
#     output (package)
#     patches (package)
#     runtime
#     sheets
#     snippets
#     sql (package)
#     syntax
# ...

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
# can also use this as linux cmd to make, view , update and delete files in google drives

# %%
# @title Magics - short cmds

# - line magics
# - cell magics

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %%writefile foo.py
print("Hello world") #creates a new file
# Out:
# Overwriting foo.py

# %%
# %run foo.py
# Out:
# Hello world

# %%
# %%html
# <marquee style='width: 100%; color: red;'><b> This is Colab</b></marquee>
# Out:
# <marquee style='width: 100%; color: red;'><b> This is Colab</b></marquee>

# %%
# %time 2**128 #amount of time it took colab to run
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 7.39 µs
# 340282366920938463463374607431768211456

# %%
import math

# %%
# %time math.factorial(15)
# Out:
# CPU times: user 165 µs, sys: 15 µs, total: 180 µs
# Wall time: 185 µs
# ...

# %%
import numpy as np

# %%
# %timeit np.linalg.eigvals(np.random.rand(100,100))
# Out:
# 4.82 ms ± 90.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %matplotlib inline #direct display the graph
